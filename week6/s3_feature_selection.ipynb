# %%
import os
import pandas as pd

base_dir = "../Data"
base_csv_path = os.path.join(base_dir, 'm0_simpleimputer_week6.csv')
output_csv_path = os.path.join(base_dir, 'm0_post_feat_sel.csv')
assert os.path.exists(base_csv_path), f"base {base_csv_path} does not exist"

df = pd.read_csv(base_csv_path)

# %%
#Print number of missing values in wl_tme
print(f'Number of missing values in wl_time: {df["wl_time"].isnull().sum()}')

#Print number of values in wl_time
print(f'Number of values in wl_time: {df["wl_time"].count()}')

wl_median = df['wl_time'].median()
# Out:
# Number of missing values in wl_time: 0
# Number of values in wl_time: 65067

# %%
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression

X = df.drop(['wl_time'], axis=1)
y = df['wl_time'].apply(lambda x: 0 if x < wl_median else 1)

# %%
from sklearn.preprocessing import StandardScaler

columns_to_scale = [col for col in X.columns if X[col].nunique() > 2]
scaler = StandardScaler()
X[columns_to_scale] = scaler.fit_transform(X[columns_to_scale])

# %%
log = LogisticRegression(max_iter=1000)

selector = RFECV(estimator=log, cv=5, scoring='f1_macro', verbose=1)
selector.fit(X, y)

print(f"Num of features: {X.shape[1]}")
print(f"Num of features recommended after feature selection: {selector.n_features_}")
# Out:
# Fitting estimator with 99 features.
# Fitting estimator with 98 features.
# Fitting estimator with 97 features.
# Fitting estimator with 96 features.
# Fitting estimator with 95 features.
# Fitting estimator with 94 features.
# Fitting estimator with 93 features.
# Fitting estimator with 92 features.
# Fitting estimator with 91 features.
# Fitting estimator with 90 features.
# Fitting estimator with 89 features.
# Fitting estimator with 88 features.
# Fitting estimator with 87 features.
# Fitting estimator with 86 features.
# Fitting estimator with 85 features.
# Fitting estimator with 84 features.
# Fitting estimator with 83 features.
# Fitting estimator with 82 features.
# Fitting estimator with 81 features.
# Fitting estimator with 80 features.
# Fitting estimator with 79 features.
# Fitting estimator with 78 features.
# Fitting estimator with 77 features.
# Fitting estimator with 76 features.
# Fitting estimator with 75 features.
# Fitting estimator with 74 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 99 features.
# Fitting estimator with 98 features.
# Fitting estimator with 97 features.
# Fitting estimator with 96 features.
# Fitting estimator with 95 features.
# Fitting estimator with 94 features.
# Fitting estimator with 93 features.
# Fitting estimator with 92 features.
# Fitting estimator with 91 features.
# Fitting estimator with 90 features.
# Fitting estimator with 89 features.
# Fitting estimator with 88 features.
# Fitting estimator with 87 features.
# Fitting estimator with 86 features.
# Fitting estimator with 85 features.
# Fitting estimator with 84 features.
# Fitting estimator with 83 features.
# Fitting estimator with 82 features.
# Fitting estimator with 81 features.
# Fitting estimator with 80 features.
# Fitting estimator with 79 features.
# Fitting estimator with 78 features.
# Fitting estimator with 77 features.
# Fitting estimator with 76 features.
# Fitting estimator with 75 features.
# Fitting estimator with 74 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 99 features.
# Fitting estimator with 98 features.
# Fitting estimator with 97 features.
# Fitting estimator with 96 features.
# Fitting estimator with 95 features.
# Fitting estimator with 94 features.
# Fitting estimator with 93 features.
# Fitting estimator with 92 features.
# Fitting estimator with 91 features.
# Fitting estimator with 90 features.
# Fitting estimator with 89 features.
# Fitting estimator with 88 features.
# Fitting estimator with 87 features.
# Fitting estimator with 86 features.
# Fitting estimator with 85 features.
# Fitting estimator with 84 features.
# Fitting estimator with 83 features.
# Fitting estimator with 82 features.
# Fitting estimator with 81 features.
# Fitting estimator with 80 features.
# Fitting estimator with 79 features.
# Fitting estimator with 78 features.
# Fitting estimator with 77 features.
# Fitting estimator with 76 features.
# Fitting estimator with 75 features.
# Fitting estimator with 74 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 99 features.
# Fitting estimator with 98 features.
# Fitting estimator with 97 features.
# Fitting estimator with 96 features.
# Fitting estimator with 95 features.
# Fitting estimator with 94 features.
# Fitting estimator with 93 features.
# Fitting estimator with 92 features.
# Fitting estimator with 91 features.
# Fitting estimator with 90 features.
# Fitting estimator with 89 features.
# Fitting estimator with 88 features.
# Fitting estimator with 87 features.
# Fitting estimator with 86 features.
# Fitting estimator with 85 features.
# Fitting estimator with 84 features.
# Fitting estimator with 83 features.
# Fitting estimator with 82 features.
# Fitting estimator with 81 features.
# Fitting estimator with 80 features.
# Fitting estimator with 79 features.
# Fitting estimator with 78 features.
# Fitting estimator with 77 features.
# Fitting estimator with 76 features.
# Fitting estimator with 75 features.
# Fitting estimator with 74 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 99 features.
# Fitting estimator with 98 features.
# Fitting estimator with 97 features.
# Fitting estimator with 96 features.
# Fitting estimator with 95 features.
# Fitting estimator with 94 features.
# Fitting estimator with 93 features.
# Fitting estimator with 92 features.
# Fitting estimator with 91 features.
# Fitting estimator with 90 features.
# Fitting estimator with 89 features.
# Fitting estimator with 88 features.
# Fitting estimator with 87 features.
# Fitting estimator with 86 features.
# Fitting estimator with 85 features.
# Fitting estimator with 84 features.
# Fitting estimator with 83 features.
# Fitting estimator with 82 features.
# Fitting estimator with 81 features.
# Fitting estimator with 80 features.
# Fitting estimator with 79 features.
# Fitting estimator with 78 features.
# Fitting estimator with 77 features.
# Fitting estimator with 76 features.
# Fitting estimator with 75 features.
# Fitting estimator with 74 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 99 features.
# Fitting estimator with 98 features.
# Fitting estimator with 97 features.
# Fitting estimator with 96 features.
# Fitting estimator with 95 features.
# Fitting estimator with 94 features.
# Fitting estimator with 93 features.
# Fitting estimator with 92 features.
# Fitting estimator with 91 features.
# Fitting estimator with 90 features.
# Fitting estimator with 89 features.
# Fitting estimator with 88 features.
# Fitting estimator with 87 features.
# Num of features: 99
# Num of features recommended after feature selection: 86

# %%
feature_rankings = list(zip(df.columns, selector.ranking_, selector.support_))
feature_rankings_sorted = sorted(feature_rankings, key=lambda x: x[1])

X_new = df[[col for col in df.columns if col in X.columns[selector.support_]]]
df_sel = pd.concat([X_new, df['wl_time']], axis=1)

log.fit(X_new, y)  # Fit to get weight coefficients

for feature, ranking, support in feature_rankings_sorted:
    print(f"Feature: {feature}, Ranking: {ranking}, Support: {support}")
# Out:
# Feature: wgt_kg_tcr, Ranking: 1, Support: True
# Feature: hgt_cm_tcr, Ranking: 1, Support: True
# Feature: most_rcnt_creat, Ranking: 1, Support: True
# Feature: tot_serum_album, Ranking: 1, Support: True
# Feature: init_age, Ranking: 1, Support: True
# Feature: init_hgt_cm_calc, Ranking: 1, Support: True
# Feature: init_wgt_kg_calc, Ranking: 1, Support: True
# Feature: wl_time, Ranking: 1, Support: True
# Feature: thoracic_dgn_1.0, Ranking: 1, Support: True
# Feature: thoracic_dgn_4.0, Ranking: 1, Support: True
# Feature: thoracic_dgn_5.0, Ranking: 1, Support: True
# Feature: thoracic_dgn_7.0, Ranking: 1, Support: True
# Feature: thoracic_dgn_missing, Ranking: 1, Support: True
# Feature: num_prev_tx_0, Ranking: 1, Support: True
# Feature: num_prev_tx_1, Ranking: 1, Support: True
# Feature: num_prev_tx_2, Ranking: 1, Support: True
# Feature: tah_N, Ranking: 1, Support: True
# Feature: tah_Y, Ranking: 1, Support: True
# Feature: tah_missing, Ranking: 1, Support: True
# Feature: vas_Y, Ranking: 1, Support: True
# Feature: vas_missing, Ranking: 1, Support: True
# Feature: onvent_N, Ranking: 1, Support: True
# Feature: onvent_Y, Ranking: 1, Support: True
# Feature: onvent_missing, Ranking: 1, Support: True
# Feature: icu_N, Ranking: 1, Support: True
# Feature: icu_Y, Ranking: 1, Support: True
# Feature: icu_missing, Ranking: 1, Support: True
# Feature: inotropic_N, Ranking: 1, Support: True
# Feature: inotropic_Y, Ranking: 1, Support: True
# Feature: inotropic_missing, Ranking: 1, Support: True
# Feature: abo_1, Ranking: 1, Support: True
# Feature: abo_2, Ranking: 1, Support: True
# Feature: abo_3, Ranking: 1, Support: True
# Feature: education_3.0, Ranking: 1, Support: True
# Feature: education_missing, Ranking: 1, Support: True
# Feature: ecmo_tcr_0, Ranking: 1, Support: True
# Feature: ecmo_tcr_1, Ranking: 1, Support: True
# Feature: iabp_tcr_0, Ranking: 1, Support: True
# Feature: iabp_tcr_1, Ranking: 1, Support: True
# Feature: inotropes_tcr_0, Ranking: 1, Support: True
# Feature: inotropes_tcr_1, Ranking: 1, Support: True
# Feature: func_stat_tcr_1.0, Ranking: 1, Support: True
# Feature: func_stat_tcr_2.0, Ranking: 1, Support: True
# Feature: func_stat_tcr_3.0, Ranking: 1, Support: True
# Feature: func_stat_tcr_missing, Ranking: 1, Support: True
# Feature: diab_1.0, Ranking: 1, Support: True
# Feature: diab_2.0, Ranking: 1, Support: True
# Feature: diab_3.0, Ranking: 1, Support: True
# Feature: diab_4.0, Ranking: 1, Support: True
# Feature: diab_5.0, Ranking: 1, Support: True
# Feature: diab_missing, Ranking: 1, Support: True
# Feature: dial_ty_tcr_1.0, Ranking: 1, Support: True
# Feature: dial_ty_tcr_2.0, Ranking: 1, Support: True
# Feature: dial_ty_tcr_3.0, Ranking: 1, Support: True
# Feature: dial_ty_tcr_missing, Ranking: 1, Support: True
# Feature: cereb_vasc_N, Ranking: 1, Support: True
# Feature: cereb_vasc_U, Ranking: 1, Support: True
# Feature: cereb_vasc_Y, Ranking: 1, Support: True
# Feature: cereb_vasc_missing, Ranking: 1, Support: True
# Feature: malig_tcr_N, Ranking: 1, Support: True
# Feature: malig_tcr_U, Ranking: 1, Support: True
# Feature: malig_tcr_Y, Ranking: 1, Support: True
# Feature: malig_tcr_missing, Ranking: 1, Support: True
# Feature: cig_use_N, Ranking: 1, Support: True
# Feature: cig_use_Y, Ranking: 1, Support: True
# Feature: cig_use_missing, Ranking: 1, Support: True
# Feature: prior_card_surg_tcr_N, Ranking: 1, Support: True
# Feature: prior_card_surg_tcr_U, Ranking: 1, Support: True
# Feature: prior_card_surg_tcr_Y, Ranking: 1, Support: True
# Feature: prior_card_surg_tcr_missing, Ranking: 1, Support: True
# Feature: histry_cig_old_U, Ranking: 1, Support: True
# Feature: histry_cig_old_Y, Ranking: 1, Support: True
# Feature: histry_cig_old_missing, Ranking: 1, Support: True
# Feature: init_stat_2.0, Ranking: 1, Support: True
# Feature: init_stat_3.0, Ranking: 1, Support: True
# Feature: init_stat_4.0, Ranking: 1, Support: True
# Feature: init_stat_missing, Ranking: 1, Support: True
# Feature: ethcat_1, Ranking: 1, Support: True
# Feature: ethcat_2, Ranking: 1, Support: True
# Feature: ethcat_4, Ranking: 1, Support: True
# Feature: ethcat_5, Ranking: 1, Support: True
# Feature: ethcat_6, Ranking: 1, Support: True
# Feature: ventilator_tcr_0, Ranking: 1, Support: True
# Feature: work_income_tcr_N, Ranking: 1, Support: True
# Feature: work_income_tcr_U, Ranking: 1, Support: True
# Feature: work_income_tcr_Y, Ranking: 1, Support: True
# Feature: num_prev_tx_3, Ranking: 2, Support: False
# Feature: vas_N, Ranking: 3, Support: False
# Feature: histry_cig_old_N, Ranking: 4, Support: False
# Feature: gender_F, Ranking: 5, Support: False
# Feature: ventilator_tcr_1, Ranking: 6, Support: False
# Feature: thoracic_dgn_2.0, Ranking: 7, Support: False
# Feature: hemo_co_tcr, Ranking: 8, Support: False
# Feature: education_1.0, Ranking: 9, Support: False
# Feature: abo_4, Ranking: 10, Support: False
# Feature: education_2.0, Ranking: 11, Support: False
# Feature: init_stat_1.0, Ranking: 12, Support: False
# Feature: gender_M, Ranking: 13, Support: False
# Feature: thoracic_dgn_3.0, Ranking: 14, Support: False
# /home/maliti/Prog/time-to-transplantation/.conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#Print the weights of the model with the corresponding feature name
weights = list(zip(X_new.columns, log.coef_[0]))
weights_sorted = sorted(weights, key=lambda x: x[1])
for feature, weight in weights_sorted:
    print(f"Feature: {feature}, Weight: {weight}")
# Out:
# Feature: init_stat_1.0, Weight: -0.9760675167281684
# Feature: abo_3, Weight: -0.8530724153295396
# Feature: inotropic_missing, Weight: -0.7251210791832868
# Feature: vas_N, Weight: -0.6834165174514238
# Feature: prior_card_surg_tcr_missing, Weight: -0.5993659193737646
# Feature: thoracic_dgn_7.0, Weight: -0.3967718876714767
# Feature: ecmo_tcr_1, Weight: -0.3811598343197136
# Feature: func_stat_tcr_missing, Weight: -0.3755366836583319
# Feature: onvent_Y, Weight: -0.3700414935457369
# Feature: inotropes_tcr_1, Weight: -0.33922295807313313
# Feature: ventilator_tcr_0, Weight: -0.3203766064833772
# Feature: icu_missing, Weight: -0.30253171387285077
# Feature: diab_2.0, Weight: -0.2979069905848901
# Feature: dial_ty_tcr_1.0, Weight: -0.287715193741497
# Feature: func_stat_tcr_3.0, Weight: -0.2748461213008878
# Feature: iabp_tcr_1, Weight: -0.25658683349724665
# Feature: malig_tcr_N, Weight: -0.23996337197214185
# Feature: malig_tcr_Y, Weight: -0.2389472778071908
# Feature: num_prev_tx_1, Weight: -0.23838092512722245
# Feature: cig_use_N, Weight: -0.23524681050524843
# Feature: diab_missing, Weight: -0.23504129552534625
# Feature: icu_Y, Weight: -0.2248574649937114
# Feature: thoracic_dgn_missing, Weight: -0.2236496278563451
# Feature: histry_cig_old_N, Weight: -0.2162818846696458
# Feature: work_income_tcr_missing, Weight: -0.20384192125123185
# Feature: dial_ty_tcr_missing, Weight: -0.19914151640912203
# Feature: ethcat_6, Weight: -0.19067556822252918
# Feature: cereb_vasc_U, Weight: -0.16655512522749108
# Feature: cereb_vasc_Y, Weight: -0.15938362335177936
# Feature: cig_use_Y, Weight: -0.15338146041381512
# Feature: ethcat_5, Weight: -0.12886824380069595
# Feature: cereb_vasc_N, Weight: -0.12496804590305516
# Feature: education_missing, Weight: -0.1249392957952665
# Feature: ethcat_4, Weight: -0.12383848177562388
# Feature: onvent_missing, Weight: -0.10368148632451435
# Feature: tah_missing, Weight: -0.09901874499877067
# Feature: iabp_tcr_0, Weight: -0.09341541679198717
# Feature: num_prev_tx_0, Weight: -0.09252745209458671
# Feature: vas_missing, Weight: -0.09070093488552444
# Feature: histry_cig_old_Y, Weight: -0.08708365317378275
# Feature: gender_F, Weight: -0.06576059336201537
# Feature: most_rcnt_creat, Weight: -0.06299863545064306
# Feature: tah_Y, Weight: -0.05155345541565512
# Feature: dial_ty_tcr_2.0, Weight: -0.050466872122782766
# Feature: num_prev_tx_2, Weight: -0.0457751330181273
# Feature: init_stat_missing, Weight: -0.0402322420670695
# Feature: ventilator_tcr_1, Weight: -0.029625643807562288
# Feature: inotropes_tcr_0, Weight: -0.01077929221405636
# Feature: init_hgt_cm_calc, Weight: -0.00565998096806863
# Feature: init_age, Weight: -0.005290514975773007
# Feature: init_wgt_kg_calc, Weight: 0.0002729676773053797
# Feature: hgt_cm_tcr, Weight: 0.009661607663078267
# Feature: diab_1.0, Weight: 0.018346761952737132
# Feature: wgt_kg_tcr, Weight: 0.02156930834138449
# Feature: malig_tcr_U, Weight: 0.023996591947994885
# Feature: prior_card_surg_tcr_U, Weight: 0.024110910007376148
# Feature: ethcat_1, Weight: 0.025731572474314807
# Feature: num_prev_tx_3, Weight: 0.02668125994970959
# Feature: ecmo_tcr_0, Weight: 0.03115758403119616
# Feature: diab_4.0, Weight: 0.03353966834198912
# Feature: thoracic_dgn_1.0, Weight: 0.03497012962896739
# Feature: cig_use_missing, Weight: 0.038626020629384014
# Feature: work_income_tcr_Y, Weight: 0.040056344241484895
# Feature: diab_3.0, Weight: 0.04238673127453444
# Feature: prior_card_surg_tcr_N, Weight: 0.049137509896942946
# Feature: ethcat_2, Weight: 0.06764847103557912
# Feature: diab_5.0, Weight: 0.08867287424916197
# Feature: abo_2, Weight: 0.09317133673507658
# Feature: cereb_vasc_missing, Weight: 0.10090454419234333
# Feature: malig_tcr_missing, Weight: 0.10491180754209528
# Feature: func_stat_tcr_2.0, Weight: 0.11188602951221574
# Feature: tot_serum_album, Weight: 0.11469293724633432
# Feature: onvent_N, Weight: 0.12372072957956025
# Feature: inotropic_N, Weight: 0.1614565431213766
# Feature: prior_card_surg_tcr_Y, Weight: 0.17611524917927115
# Feature: thoracic_dgn_2.0, Weight: 0.17693564057081704
# Feature: icu_N, Weight: 0.17738692857629215
# Feature: dial_ty_tcr_3.0, Weight: 0.1873213319833717
# Feature: func_stat_tcr_1.0, Weight: 0.18849452515465864
# Feature: work_income_tcr_U, Weight: 0.20632086012502499
# Feature: histry_cig_old_missing, Weight: 0.20916416143536903
# Feature: inotropic_Y, Weight: 0.21366228577273785
# Feature: thoracic_dgn_5.0, Weight: 0.2904917469463539
# Feature: init_stat_4.0, Weight: 0.47478074860128106
# Feature: init_stat_3.0, Weight: 0.6366845773955002
# Feature: abo_4, Weight: 0.7763799266997533

# %%
df_sel.to_csv(output_csv_path, index=False)
