# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("Data_120294_2023-03-29.csv")
# Out:
# /var/folders/k_/917q0lsn2g199rm9y4s8jy5h0000gn/T/ipykernel_67476/2197491256.py:1: DtypeWarning: Columns (2,64,91,94,97,106,108,109,110,111,112,114,116,119,120,122,127,139,142,143,144,145,152,153,154,155,156,157,159,160,161,163,164,165,169,170,171,172,175,178,179,180,187,189,215,216,217,218,219,317,318) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Data_120294_2023-03-29.csv")

# %% [markdown]
# ## Choosing features and y
# choosing which features should included in the model

# %%
#Choosing the columns that we want to use
relevant_colums = ["init_age", "gender", "abo", "pramr", "prapk", "hemo_pcw_tcr", "hemo_pa_mn_tcr", "bmi_tcr",
                   "init_date", "tx_date"]

df = df[relevant_colums]

# %%
# Illustrate the data set of the chosen features with 15 random rows
df.sample(15)
# Out:
#         init_age gender abo  pramr  prapk  hemo_pcw_tcr  hemo_pa_mn_tcr  \
# 57698       58.0      M   O    NaN    NaN          10.0            20.0
# 39292       52.0      F   O    NaN    NaN          15.0            34.0
# 36042       38.0      M   O    NaN    NaN           NaN             NaN
# 3454         0.0      F   A    NaN    NaN           NaN             NaN
# 17772       57.0      M   O    NaN    NaN          14.0            22.0
# 83573       63.0      M   A    NaN    NaN          25.0            35.0
# 55346        2.0      M   A    NaN    NaN           NaN            12.0
# 91955       59.0      F   A    NaN    NaN          23.0            28.0
# 74615       62.0      M   A    0.0    4.0           NaN             NaN
# 48363       14.0      M   O    NaN    NaN           NaN             NaN
# 35879       63.0      F   O    NaN    NaN          12.0            30.0
# 104647      46.0      M   A    NaN    NaN          16.0            26.0
# 80976       68.0      M   B    NaN    NaN           NaN            35.0
# 50481       52.0      M   B    NaN    NaN          35.0            40.0
# 74744       43.0      F   A    0.0   35.0          24.0            32.0
#
#         bmi_tcr  init_date    tx_date
# 57698   26.4995  14may2007  03may2008
# 39292   40.6975  20feb2008        NaN
# 36042       NaN  12jan1990        NaN
# 3454    14.7929  25feb1994        NaN
# 17772   32.1425  09jun2004        NaN
# 83573   20.8220  03apr2009  08may2009
# 55346   16.6014  05dec1997  08jan1998
# 91955   24.7617  24may2012  16jul2012
# 74615       NaN  19jul1994  25oct1994
# 48363   23.3443  06jul2005  08dec2006
# 35879   27.4121  03jun2016        NaN
# 104647  30.7866  31aug2015  21sep2016
# 80976   24.9468  30jan2008  18feb2008
# 50481   20.2039  18jan2008  22jan2008
# 74744   24.8090  17jun2002  21jun2002

# %%
#Display some basic info about the chosen features
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120264 entries, 0 to 120263
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   init_age        120257 non-null  float64
#  1   gender          120264 non-null  object
#  2   abo             120264 non-null  object
#  3   pramr           32023 non-null   float64
#  4   prapk           30295 non-null   float64
#  5   hemo_pcw_tcr    80933 non-null   float64
#  6   hemo_pa_mn_tcr  83439 non-null   float64
#  7   bmi_tcr         115677 non-null  float64
#  8   init_date       120264 non-null  object
#  9   tx_date         77410 non-null   object
# dtypes: float64(6), object(4)
# memory usage: 9.2+ MB

# %% [markdown]
# ## Data preprocessing (cleaning) and data analysis

# %% [markdown]
# #### tx_date
# Before we start analyzing the data, we remove all rows which do not have tx_date. We are predicting time until transplant, and the rows which do not have a transplant date are therefore irrelevant.

# %%
original_size = len(df)

#Print number of rows before removing rows without tx_date
print("Number of rows before removing rows without tx_date: ", original_size)

#Remove all rows without tx_date
df = df[df["tx_date"].notna()]

size_post_cleaning = len(df)
#Print number of rows after removing rows without tx_date
print("Number of rows after removing rows without tx_date: ", size_post_cleaning)

#Print number of removed rows as number
print("Number of removed rows: ", original_size - size_post_cleaning)
# Out:
# Number of rows before removing rows without tx_date:  120264
# Number of rows after removing rows without tx_date:  77410
# Number of removed rows:  42854

# %% [markdown]
# #### Handling of duplicate values

# %%
#Display information about the duplicates
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [init_age, gender, abo, pramr, prapk, hemo_pcw_tcr, hemo_pa_mn_tcr, bmi_tcr, init_date, tx_date]
# Index: []

# %%
#Count number of duplicates
print("Number of duplicates: ", df.duplicated().sum())

#Number of duplicates before dropping
print("Number of rows before dropping duplicates: ", df.shape[0])
#Drop duplicates and keep the first occurence
df = df.drop_duplicates()

#Number of duplicates after dropping
print("Number of rows after dropping duplicates: ", df.shape[0])
# Out:
# Number of duplicates:  0
# Number of rows before dropping duplicates:  77410
# Number of rows after dropping duplicates:  77410

# %% [markdown]
# ### Handling and analysis of missing values

# %%
#Display percentage of missing values for each feature
df.isnull().sum() / df.shape[0] * 100
# Out:
# init_age           0.000000
# gender             0.000000
# abo                0.000000
# pramr             58.631960
# prapk             60.864229
# hemo_pcw_tcr      30.565818
# hemo_pa_mn_tcr    28.482108
# bmi_tcr            1.993283
# init_date          0.000000
# tx_date            0.000000
# dtype: float64

# %% [markdown]
# pramr and prapk have a lot of missing values and may need to be dropped.
# It may also be relevant to only keep the rows which have a tx_date, as the others can be considered to not have received a transplant for various reasons such as death. Imputation is needed on features with a lot of missing values.

# %% [markdown]
# #### bmi_tcr
# As there are only less than 2% of values missing a bmi_tcr, they are removed.

# %%
#Print number of rows before removing rows with missing bmi_tcr
print("Number of rows before removing rows with missing bmi_tcr: ", len(df))

#Remove all rows with missing bmi_tcr
df = df[df["bmi_tcr"].notna()]

#Print number of rows after removing rows with missing bmi_tcr
print("Number of rows after removing rows with missing bmi_tcr: ", len(df))
# Out:
# Number of rows before removing rows with missing bmi_tcr:  77410
# Number of rows after removing rows with missing bmi_tcr:  75867

# %%
#Remove all entries with missing values
#df = df.dropna()

# Use simple imputer instead of .dropna to impute missing values


#Display percentage of missing values for each feature
print(df.isnull().sum() / df.shape[0] * 100)

#Print number of rows
print("Number of rows: ", df.shape[0])
# Out:
# init_age           0.000000
# gender             0.000000
# abo                0.000000
# pramr             59.361778
# prapk             61.387692
# hemo_pcw_tcr      29.595213
# hemo_pa_mn_tcr    27.478350
# bmi_tcr            0.000000
# init_date          0.000000
# tx_date            0.000000
# dtype: float64
# Number of rows:  75867

# %% [markdown]
# #### Wait list time (wl_time) - Y
# Creating the value to be predicted, namely wl_time by calculating the difference between init_date and tx_date, and adding it to a column called wl_time. Thereafter they are dropped (maybe they shouldn't be dropped as they can be used as features?).

# %%
df['wl_time'] = (
            pd.to_datetime(df['tx_date'], format='%d%b%Y') - pd.to_datetime(df['init_date'], format='%d%b%Y')).dt.days

# drop init_date and end_date
df = df.drop(['init_date', 'tx_date'], axis=1)

# %% [markdown]
# Data visualisation and analysis on wl_time

# %%
#Display a histogram plot of wl_time using sns
sns.histplot(data=df, x="wl_time")

#print the number of values that are less than 10 in wl_time
print("Number of values less than 10 in wl_time: ", len(df[df['wl_time'] < 10]))

#Print the median of the wl_time
median_wl_time = df['wl_time'].median()
print(median_wl_time)
# Out:
# Number of values less than 10 in wl_time:  9365
# 79.0

# %%
#Display a boxplot of the distribution of the wl_time using sns
sns.boxplot(data=df, x="wl_time")

#Print the number of values that that are outliers, meaning they are bigger than 500
print("Number of values that are outliers in wl_time: ", len(df[df['wl_time'] > 500]))
#Print the number of values that are not outliers, meaning they are between 0 and 500
print("Number of values that are not outliers in wl_time: ", len(df[df['wl_time'] <= 500]))
# Out:
# Number of values that are outliers in wl_time:  7513
# Number of values that are not outliers in wl_time:  68354

# %% [markdown]
# ## Transforming
# - Drop redundant columns

# %% [markdown]
# ## Encode

# %%
# encode categorical variables
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

le = LabelEncoder()
df["abo"] = le.fit_transform(df["abo"])
df["gender"] = le.fit_transform(df["gender"])

#This should be moved to proper place later
#Calculate median wl_time


# we want to predict if it took more or less than 60 days to get a transplant
df['wl_time'] = df['wl_time'].apply(lambda x: 1 if x > median_wl_time else 0)

#for col in df.columns:
#    if df[col].dtype == 'object':
#        df[col] = le.fit_transform(df[col])

features = ["init_age", "bmi_tcr", "pramr", "prapk", "hemo_pcw_tcr", "hemo_pa_mn_tcr"]
scaler = StandardScaler()
df[features] = scaler.fit_transform(df[features])

# Impute missing values
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
df = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# %% [markdown]
# ## Build model

# %%
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
# import ClassificationReport for confusion matrix
from sklearn.metrics import classification_report


assert df.isnull().sum().sum() == 0, "There are still missing values in the dataset"

X_train, X_test, y_train, y_test = train_test_split(df.drop('wl_time', axis=1), df['wl_time'], test_size=0.2,
                                                    random_state=42)

lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
print("Logistic Regression Accuracy: ", accuracy_score(y_test, y_pred))
# Out:
# Logistic Regression Accuracy:  0.5626729932779755

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)
classes = {
    1: "Under 60 days",
    0: "Over 60 days"
}
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes.values())
disp.plot()

# %%
# import correlation matrix
import seaborn as sns

df.corr()
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot: >

# %%
model = Sequential([
    Dense(64, activation="relu"),
    Dropout(0.2),
    Dense(32, activation="relu"),
    Dropout(0.2),
    Dense(1, activation="sigmoid")
])

# compile the model
#model.compile(loss='mse', optimizer='adam', metrics=['mae'])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=30, batch_size=16, verbose=1)

y_pred = model.predict(X_test)
# Out:
# Epoch 1/30
# 3794/3794 [==============================] - 2s 468us/step - loss: 0.6814 - accuracy: 0.5608
# Epoch 2/30
# 3794/3794 [==============================] - 2s 470us/step - loss: 0.6739 - accuracy: 0.5770
# Epoch 3/30
# 3794/3794 [==============================] - 2s 478us/step - loss: 0.6713 - accuracy: 0.5838
# Epoch 4/30
# 3794/3794 [==============================] - 2s 456us/step - loss: 0.6691 - accuracy: 0.5844
# Epoch 5/30
# 3794/3794 [==============================] - 2s 459us/step - loss: 0.6681 - accuracy: 0.5892
# Epoch 6/30
# 1198/3794 [========>.....................] - ETA: 1s - loss: 0.6657 - accuracy: 0.5898
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[184], line 13
#       9 # compile the model
#      10 #model.compile(loss='mse', optimizer='adam', metrics=['mae'])
#      12 model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# ---> 13 model.fit(X_train, y_train, epochs=30, batch_size=16, verbose=1)
#      15 y_pred = model.predict(X_test)
#
# File /opt/homebrew/anaconda3/envs/edap01/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/homebrew/anaconda3/envs/edap01/lib/python3.10/site-packages/keras/engine/training.py:1650, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1642 with tf.profiler.experimental.Trace(
#    1643     "train",
#    1644     epoch_num=epoch,
#    (...)
#    1647     _r=1,
#    1648 ):
#    1649     callbacks.on_train_batch_begin(step)
# -> 1650     tmp_logs = self.train_function(iterator)
#    1651     if data_handler.should_sync:
#    1652         context.async_wait()
#
# File /opt/homebrew/anaconda3/envs/edap01/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/homebrew/anaconda3/envs/edap01/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:880, in Function.__call__(self, *args, **kwds)
#     877 compiler = "xla" if self._jit_compile else "nonXla"
#     879 with OptionalXlaContext(self._jit_compile):
# --> 880   result = self._call(*args, **kwds)
#     882 new_tracing_count = self.experimental_get_tracing_count()
#     883 without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/homebrew/anaconda3/envs/edap01/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:912, in Function._call(self, *args, **kwds)
#     909   self._lock.release()
#     910   # In this case we have created variables on the first call, so we run the
#     911   # defunned version which is guaranteed to never create variables.
# --> 912   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913 elif self._variable_creation_fn is not None:
#     914   # Release the lock early so that multiple threads can perform the call
#     915   # in parallel.
#     916   self._lock.release()
#
# File /opt/homebrew/anaconda3/envs/edap01/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:133, in TracingCompiler.__call__(self, *args, **kwargs)
#     130 """Calls a graph function specialized to the inputs."""
#     131 with self._lock:
#     132   (concrete_function,
# --> 133    filtered_flat_args) = self._maybe_define_function(args, kwargs)
#     134 return concrete_function._call_flat(
#     135     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File /opt/homebrew/anaconda3/envs/edap01/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:336, in TracingCompiler._maybe_define_function(self, args, kwargs)
#     331 captures = self._captures_container.get_snapshot()
#     333 # cache_key_deletion_observer is useless here. It's based on all captures.
#     334 # A new cache key will be built later when saving ConcreteFunction because
#     335 # only active captures should be saved.
# --> 336 lookup_func_key, _ = function_context.make_cache_key((args, kwargs),
#     337                                                      captures)
#     338 concrete_function = self._function_cache.lookup(lookup_func_key, True)
#     339 if concrete_function is not None:
#
# File /opt/homebrew/anaconda3/envs/edap01/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/function_context.py:133, in make_cache_key(args, captures)
#     131   captures = dict()
#     132 signature_context = trace_type.InternalTracingContext()
# --> 133 args_signature = trace_type.from_value(
#     134     args, signature_context)
#     135 captures_dict_tracetype = trace_type.from_value(
#     136     captures, signature_context)
#     138 # TODO(fmuham): Use the actual FunctionType
#
# File /opt/homebrew/anaconda3/envs/edap01/lib/python3.10/site-packages/tensorflow/core/function/trace_type/trace_type_builder.py:114, in from_value(value, context)
#     112 if context.is_legacy_signature and isinstance(value, trace.TraceType):
#     113   return value
# --> 114 elif isinstance(value, trace.SupportsTracingProtocol):
#     115   return value.__tf_tracing_type__(context)
#     117 if hasattr(value, "__wrapped__"):
#
# File /opt/homebrew/anaconda3/envs/edap01/lib/python3.10/typing.py:1510, in _ProtocolMeta.__instancecheck__(cls, instance)
#    1504     return True
#    1505 if cls._is_protocol:
#    1506     if all(hasattr(instance, attr) and
#    1507             # All *methods* can be blocked by setting them to None.
#    1508             (not callable(getattr(cls, attr, None)) or
#    1509              getattr(instance, attr) is not None)
# -> 1510             for attr in _get_protocol_attrs(cls)):
#    1511         return True
#    1512 return super().__instancecheck__(instance)
#
# File /opt/homebrew/anaconda3/envs/edap01/lib/python3.10/typing.py:1420, in _get_protocol_attrs(cls)
#    1418     annotations = getattr(base, '__annotations__', {})
#    1419     for attr in list(base.__dict__.keys()) + list(annotations.keys()):
# -> 1420         if not attr.startswith('_abc_') and attr not in EXCLUDED_ATTRIBUTES:
#    1421             attrs.add(attr)
#    1422 return attrs
#
# KeyboardInterrupt:
