# %%
# check installed version
import pycaret
pycaret.__version__
# Out:
# '3.0.2'

# %%
import pandas as pd
import os

base_dir = "../Data"
base_csv_path = os.path.join(base_dir, 'base_cleaned.csv')
assert os.path.exists(base_csv_path), f"base {base_csv_path} does not exist"

# Load the data
df = pd.read_csv(base_csv_path)

# %%
#Calculate the median in wl_time
median = df['wl_time'].median()

#Print the the median wainting time
print("The median waiting time is: ", median)

#Code wl_time to 0 if it is less than the median, otherwise 1
df['wl_time'] = df['wl_time'].apply(lambda x: 0 if x < median else 1)
# Out:
# The median waiting time is:  88.0

# %%
df.sample(5)
# Out:
#        thoracic_dgn  num_prev_tx  tah  vas onvent  icu inotropic gender  abo  \
# 50319           1.0            0  NaN  NaN    NaN  NaN       NaN      M    4
# 52195           1.0            0  NaN  NaN    NaN  NaN       NaN      F    1
# 51948           1.0            0  NaN  NaN    NaN  NaN       NaN      F    1
# 58853           1.0            0  NaN  NaN    NaN  NaN       NaN      M    1
# 63978           4.0            1    N    N      N    N       NaN      M    2
#
#        wgt_kg_tcr  ...  prior_card_surg_tcr  histry_cig_old  init_stat  \
# 50319     86.5000  ...                    N             NaN        2.0
# 52195     84.8000  ...                    N             NaN        2.0
# 51948     64.4101  ...                    Y             NaN        2.0
# 58853    110.6770  ...                    N             NaN        2.0
# 63978     89.0000  ...                    U             NaN        3.0
#
#        init_age  ethcat  init_hgt_cm_calc  init_wgt_kg_calc  ventilator_tcr  \
# 50319      38.0       1            180.34           86.5000               0
# 52195      54.0       2            162.56           84.8000               0
# 51948      65.0       1            154.94           64.4101               0
# 58853      53.0       2            175.26          110.6770               0
# 63978      42.0       1            172.00           89.0000               0
#
#       work_income_tcr wl_time
# 50319               N       1
# 52195               N       1
# 51948               N       0
# 58853               N       1
# 63978             NaN       0
#
# [5 rows x 34 columns]

# %%
# import pycaret classification and init setup
from pycaret.classification import *
s = setup(df, target = 'wl_time', normalize=True, session_id = 123)
# Out:
# <style type="text/css">
# #T_b84b3_row11_col1, #T_b84b3_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b84b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b84b3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b84b3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b84b3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b84b3_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b84b3_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b84b3_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b84b3_row1_col1" class="data row1 col1" >wl_time</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b84b3_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_b84b3_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b84b3_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_b84b3_row3_col1" class="data row3 col1" >(65067, 34)</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b84b3_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_b84b3_row4_col1" class="data row4 col1" >(65067, 44)</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b84b3_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_b84b3_row5_col1" class="data row5 col1" >(45546, 44)</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b84b3_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_b84b3_row6_col1" class="data row6 col1" >(19521, 44)</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b84b3_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_b84b3_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b84b3_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_b84b3_row8_col1" class="data row8 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b84b3_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_b84b3_row9_col1" class="data row9 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b84b3_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_b84b3_row10_col1" class="data row10 col1" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b84b3_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_b84b3_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b84b3_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_b84b3_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b84b3_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_b84b3_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b84b3_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_b84b3_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b84b3_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_b84b3_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b84b3_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_b84b3_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b84b3_row17_col0" class="data row17 col0" >Normalize</td>
#       <td id="T_b84b3_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b84b3_row18_col0" class="data row18 col0" >Normalize method</td>
#       <td id="T_b84b3_row18_col1" class="data row18 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_b84b3_row19_col0" class="data row19 col0" >Fold Generator</td>
#       <td id="T_b84b3_row19_col1" class="data row19 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_b84b3_row20_col0" class="data row20 col0" >Fold Number</td>
#       <td id="T_b84b3_row20_col1" class="data row20 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_b84b3_row21_col0" class="data row21 col0" >CPU Jobs</td>
#       <td id="T_b84b3_row21_col1" class="data row21 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_b84b3_row22_col0" class="data row22 col0" >Use GPU</td>
#       <td id="T_b84b3_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_b84b3_row23_col0" class="data row23 col0" >Log Experiment</td>
#       <td id="T_b84b3_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_b84b3_row24_col0" class="data row24 col0" >Experiment Name</td>
#       <td id="T_b84b3_row24_col1" class="data row24 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_b84b3_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_b84b3_row25_col0" class="data row25 col0" >USI</td>
#       <td id="T_b84b3_row25_col1" class="data row25 col1" >3ce2</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_89888 th {
#   text-align: left;
# }
# #T_89888_row0_col0, #T_89888_row0_col3, #T_89888_row1_col0, #T_89888_row1_col1, #T_89888_row1_col2, #T_89888_row1_col3, #T_89888_row1_col4, #T_89888_row1_col5, #T_89888_row1_col6, #T_89888_row1_col7, #T_89888_row2_col0, #T_89888_row2_col1, #T_89888_row2_col2, #T_89888_row2_col3, #T_89888_row2_col4, #T_89888_row2_col5, #T_89888_row2_col6, #T_89888_row2_col7, #T_89888_row3_col0, #T_89888_row3_col1, #T_89888_row3_col2, #T_89888_row3_col3, #T_89888_row3_col4, #T_89888_row3_col5, #T_89888_row3_col6, #T_89888_row3_col7, #T_89888_row4_col0, #T_89888_row4_col1, #T_89888_row4_col2, #T_89888_row4_col3, #T_89888_row4_col4, #T_89888_row4_col5, #T_89888_row4_col6, #T_89888_row4_col7, #T_89888_row5_col0, #T_89888_row5_col1, #T_89888_row5_col2, #T_89888_row5_col3, #T_89888_row5_col4, #T_89888_row5_col5, #T_89888_row5_col6, #T_89888_row5_col7, #T_89888_row6_col0, #T_89888_row6_col1, #T_89888_row6_col2, #T_89888_row6_col3, #T_89888_row6_col4, #T_89888_row6_col5, #T_89888_row6_col6, #T_89888_row6_col7, #T_89888_row7_col0, #T_89888_row7_col1, #T_89888_row7_col2, #T_89888_row7_col3, #T_89888_row7_col4, #T_89888_row7_col5, #T_89888_row7_col6, #T_89888_row7_col7, #T_89888_row8_col0, #T_89888_row8_col1, #T_89888_row8_col2, #T_89888_row8_col3, #T_89888_row8_col4, #T_89888_row8_col5, #T_89888_row8_col6, #T_89888_row8_col7, #T_89888_row9_col0, #T_89888_row9_col1, #T_89888_row9_col2, #T_89888_row9_col3, #T_89888_row9_col4, #T_89888_row9_col5, #T_89888_row9_col6, #T_89888_row9_col7, #T_89888_row10_col0, #T_89888_row10_col1, #T_89888_row10_col2, #T_89888_row10_col3, #T_89888_row10_col4, #T_89888_row10_col5, #T_89888_row10_col6, #T_89888_row10_col7, #T_89888_row11_col0, #T_89888_row11_col1, #T_89888_row11_col2, #T_89888_row11_col3, #T_89888_row11_col4, #T_89888_row11_col5, #T_89888_row11_col6, #T_89888_row11_col7, #T_89888_row12_col0, #T_89888_row12_col1, #T_89888_row12_col2, #T_89888_row12_col3, #T_89888_row12_col4, #T_89888_row12_col5, #T_89888_row12_col6, #T_89888_row12_col7, #T_89888_row13_col0, #T_89888_row13_col1, #T_89888_row13_col2, #T_89888_row13_col3, #T_89888_row13_col4, #T_89888_row13_col5, #T_89888_row13_col6, #T_89888_row13_col7, #T_89888_row14_col0, #T_89888_row14_col1, #T_89888_row14_col2, #T_89888_row14_col3, #T_89888_row14_col4, #T_89888_row14_col5, #T_89888_row14_col6, #T_89888_row14_col7, #T_89888_row15_col0, #T_89888_row15_col1, #T_89888_row15_col2, #T_89888_row15_col4, #T_89888_row15_col5, #T_89888_row15_col6, #T_89888_row15_col7 {
#   text-align: left;
# }
# #T_89888_row0_col1, #T_89888_row0_col2, #T_89888_row0_col4, #T_89888_row0_col5, #T_89888_row0_col6, #T_89888_row0_col7, #T_89888_row15_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_89888_row0_col8, #T_89888_row1_col8, #T_89888_row2_col8, #T_89888_row3_col8, #T_89888_row4_col8, #T_89888_row5_col8, #T_89888_row6_col8, #T_89888_row8_col8, #T_89888_row9_col8, #T_89888_row10_col8, #T_89888_row11_col8, #T_89888_row12_col8, #T_89888_row13_col8, #T_89888_row14_col8, #T_89888_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_89888_row7_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_89888">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89888_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_89888_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_89888_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_89888_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_89888_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_89888_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_89888_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_89888_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_89888_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89888_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_89888_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_89888_row0_col1" class="data row0 col1" >0.7010</td>
#       <td id="T_89888_row0_col2" class="data row0 col2" >0.7686</td>
#       <td id="T_89888_row0_col3" class="data row0 col3" >0.7180</td>
#       <td id="T_89888_row0_col4" class="data row0 col4" >0.6956</td>
#       <td id="T_89888_row0_col5" class="data row0 col5" >0.7066</td>
#       <td id="T_89888_row0_col6" class="data row0 col6" >0.4020</td>
#       <td id="T_89888_row0_col7" class="data row0 col7" >0.4022</td>
#       <td id="T_89888_row0_col8" class="data row0 col8" >0.2570</td>
#     </tr>
#     <tr>
#       <th id="T_89888_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_89888_row1_col0" class="data row1 col0" >CatBoost Classifier</td>
#       <td id="T_89888_row1_col1" class="data row1 col1" >0.7003</td>
#       <td id="T_89888_row1_col2" class="data row1 col2" >0.7681</td>
#       <td id="T_89888_row1_col3" class="data row1 col3" >0.7168</td>
#       <td id="T_89888_row1_col4" class="data row1 col4" >0.6951</td>
#       <td id="T_89888_row1_col5" class="data row1 col5" >0.7058</td>
#       <td id="T_89888_row1_col6" class="data row1 col6" >0.4005</td>
#       <td id="T_89888_row1_col7" class="data row1 col7" >0.4008</td>
#       <td id="T_89888_row1_col8" class="data row1 col8" >8.7750</td>
#     </tr>
#     <tr>
#       <th id="T_89888_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_89888_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_89888_row2_col1" class="data row2 col1" >0.6999</td>
#       <td id="T_89888_row2_col2" class="data row2 col2" >0.7675</td>
#       <td id="T_89888_row2_col3" class="data row2 col3" >0.7192</td>
#       <td id="T_89888_row2_col4" class="data row2 col4" >0.6937</td>
#       <td id="T_89888_row2_col5" class="data row2 col5" >0.7062</td>
#       <td id="T_89888_row2_col6" class="data row2 col6" >0.3997</td>
#       <td id="T_89888_row2_col7" class="data row2 col7" >0.4000</td>
#       <td id="T_89888_row2_col8" class="data row2 col8" >1.1550</td>
#     </tr>
#     <tr>
#       <th id="T_89888_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_89888_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_89888_row3_col1" class="data row3 col1" >0.6967</td>
#       <td id="T_89888_row3_col2" class="data row3 col2" >0.7624</td>
#       <td id="T_89888_row3_col3" class="data row3 col3" >0.7146</td>
#       <td id="T_89888_row3_col4" class="data row3 col4" >0.6912</td>
#       <td id="T_89888_row3_col5" class="data row3 col5" >0.7027</td>
#       <td id="T_89888_row3_col6" class="data row3 col6" >0.3934</td>
#       <td id="T_89888_row3_col7" class="data row3 col7" >0.3937</td>
#       <td id="T_89888_row3_col8" class="data row3 col8" >0.4750</td>
#     </tr>
#     <tr>
#       <th id="T_89888_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_89888_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_89888_row4_col1" class="data row4 col1" >0.6928</td>
#       <td id="T_89888_row4_col2" class="data row4 col2" >0.7581</td>
#       <td id="T_89888_row4_col3" class="data row4 col3" >0.7073</td>
#       <td id="T_89888_row4_col4" class="data row4 col4" >0.6886</td>
#       <td id="T_89888_row4_col5" class="data row4 col5" >0.6978</td>
#       <td id="T_89888_row4_col6" class="data row4 col6" >0.3856</td>
#       <td id="T_89888_row4_col7" class="data row4 col7" >0.3858</td>
#       <td id="T_89888_row4_col8" class="data row4 col8" >1.0760</td>
#     </tr>
#     <tr>
#       <th id="T_89888_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_89888_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_89888_row5_col1" class="data row5 col1" >0.6885</td>
#       <td id="T_89888_row5_c

# %%
plot_model(best, plot = 'confusion_matrix')

# %%
plot_model(best, plot = 'auc')

# %%
plot_model(best, plot = 'feature')
